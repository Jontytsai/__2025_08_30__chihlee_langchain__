# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        }
        
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T07:56:34.648507Z', 'response': '想像一下 Python 函式就像一個 **程式的指令**，告訴 Python 程式做什麼。\n\n**簡單來說，Python 函式就是：**\n\n1. **一個特定任務的步驟。** 就像你做一個蛋糕，你需要做一些步驟，比如混合材料、烤蛋糕等。\n2. **可以重複執行。** 就像你重複做步驟，讓蛋糕烤好。\n3. **可以接收參數（輸入）。**  你給蛋糕的材料，這樣才能烤出好的蛋糕。  Python 函式也接收參數，像是給它一些輸入。\n4. **輸出結果（結果）。**  你烤好蛋糕後，才能品嚐。  Python 函式輸出結果，像是顯示結果、計算結果等。\n\n**舉個例子：**\n\n假設你想計算 2 + 2：\n\n*   **函式：** `calculate_sum(a, b)`  (這個函式會計算 `a` 和 `b` 的和)\n*   **輸入：** `a = 2`， `b = 2`\n*   **執行：**  計算 `a + b = 4`\n*   **輸出：** `4`\n\n**Python 函式可以有不同的形式：**\n\n*   **單一函式 (Single Function):**  一個函式只做一個事情，可以重複使用。\n*   **多個函式 (Multiple Functions):**  可以有很多個函式，每個函式做不同的事情。\n\n**總結：**\n\nPython 函式就像程式的指令，它們可以重複執行，並根據不同的輸入提供不同的結果。  它們是 Python 程式的骨幹！\n\n希望這個解釋對你有幫助！\n', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 239230, 237105, 74624, 48280, 185411, 26549, 237026, 32651, 236918, 238780, 237522, 237536, 106, 107, 105, 4368, 107, 103146, 19757, 17856, 236743, 238780, 237522, 55326, 19966, 5213, 47972, 236918, 81582, 1018, 236900, 146132, 17856, 236743, 47972, 237893, 26549, 236924, 108, 1018, 74624, 94757, 236900, 32651, 236743, 238780, 237522, 7888, 237184, 1018, 108, 236770, 236761, 5213, 19966, 60009, 152807, 236918, 167951, 236924, 1018, 236743, 55326, 237408, 237893, 19966, 121407, 236900, 212051, 237893, 18303, 167951, 236900, 30546, 60478, 29314, 236951, 241483, 121407, 237520, 236924, 107, 236778, 236761, 5213, 5157, 174322, 78204, 236924, 1018, 236743, 55326, 237408, 174322, 237893, 167951, 236900, 239301, 121407, 241483, 237389, 236924, 107, 236800, 236761, 5213, 5157, 70667, 209458, 237221, 62588, 21719, 1018, 138, 237408, 238966, 121407, 236918, 29314, 236900, 42991, 37272, 241483, 237191, 18518, 121407, 236924, 138, 32651, 236743, 238780, 237522, 237349, 70667, 209458, 236900, 95714, 238966, 238010, 18303, 62588, 236924, 107, 236812, 236761, 5213, 185992, 27654, 237221, 27654, 21719, 1018, 138, 237408, 241483, 237389, 121407, 237702, 236900, 37272, 237344, 245371, 236924, 138, 32651, 236743, 238780, 237522, 185992, 27654, 236900, 95714, 105832, 27654, 236951, 44068, 27654, 237520, 236924, 108, 1018, 241127, 237629, 69954, 237184, 1018, 108, 206402, 143206, 44068, 236743, 236778, 900, 236743, 236778, 237184, 108, 236829, 139, 1018, 238780, 237522, 237184, 1018, 2165, 30718, 236779, 2330, 236769, 236746, 236764, 518, 54557, 138, 236769, 17161, 238780, 237522, 238003, 44068, 2165, 236746, 236929, 26595, 2165, 236763, 236929, 10363, 237206, 236768, 107, 236829, 139, 1018, 62588, 237184, 1018, 2165, 236746, 578, 236743, 236778, 236929, 236900, 2165, 236763, 578, 236743, 236778, 236929, 107, 236829, 139, 1018, 78204, 237184, 1018, 138, 44068, 2165, 236746, 900, 518, 578, 236743, 236812, 236929, 107, 236829, 139, 1018, 185992, 237184, 1018, 2165, 236812, 236929, 108, 1018, 32651, 236743, 238780, 237522, 5157, 237078, 35078, 36669, 237184, 1018, 108, 236829, 139, 1018, 239480, 237009, 238780, 237522, 568, 19049, 12939, 1473, 1018, 138, 19966, 238780, 237522, 237787, 237893, 19966, 25606, 236900, 5157, 174322, 5938, 236924, 107, 236829, 139, 1018, 237309, 237629, 238780, 237522, 568, 48873, 39104, 1473, 1018, 138, 5157, 74946, 237629, 238780, 237522, 236900, 117680, 238780, 237522, 237893, 35078, 25606, 236924, 108, 1018, 240018, 238331, 237184, 1018, 108, 32651, 236743, 238780, 237522, 55326, 47972, 236918, 81582, 236900, 162576, 5157, 174322, 78204, 236900, 238953, 99647, 35078, 62588, 12680, 35078, 27654, 236924, 138, 162576, 237026, 17856, 236743, 47972, 236918, 239577, 241043, 237354, 108, 21226, 17161, 185411, 238403, 126302, 116904, 237354, 107], 'total_duration': 2686911375, 'load_duration': 97880250, 'prompt_eval_count': 21, 'prompt_eval_duration': 27557458, 'eval_count': 374, 'eval_duration': 2561138125}
# 想像一下 Python 函式就像一個 **程式的指令**，告訴 Python 程式做什麼。
#
# **簡單來說，Python 函式就是：**
#
# 1. **一個特定任務的步驟。** 就像你做一個蛋糕，你需要做一些步驟，比如混合材料、烤蛋糕等。
# 2. **可以重複執行。** 就像你重複做步驟，讓蛋糕烤好。
# 3. **可以接收參數（輸入）。**  你給蛋糕的材料，這樣才能烤出好的蛋糕。  Python 函式也接收參數，像是給它一些輸入。
# 4. **輸出結果（結果）。**  你烤好蛋糕後，才能品嚐。  Python 函式輸出結果，像是顯示結果、計算結果等。
#
# **舉個例子：**
#
# 假設你想計算 2 + 2：
#
# *   **函式：** `calculate_sum(a, b)`  (這個函式會計算 `a` 和 `b` 的和)
# *   **輸入：** `a = 2`， `b = 2`
# *   **執行：**  計算 `a + b = 4`
# *   **輸出：** `4`
#
# **Python 函式可以有不同的形式：**
#
# *   **單一函式 (Single Function):**  一個函式只做一個事情，可以重複使用。
# *   **多個函式 (Multiple Functions):**  可以有很多個函式，每個函式做不同的事情。
#
# **總結：**
#
# Python 函式就像程式的指令，它們可以重複執行，並根據不同的輸入提供不同的結果。  它們是 Python 程式的骨幹！
#
# 希望這個解釋對你有幫助！
